# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 56EC-209E
#
#  Directory of C:\GIT\ML-AI-Engineering
#
# 12.09.2026  13:56    <DIR>          .
# 12.09.2026  11:06    <DIR>          ..
# 12.09.2026  11:06               184 .gitignore
# 12.09.2026  13:56    <DIR>          .idea
# 12.09.2026  11:12    <DIR>          .venv
# 12.09.2026  11:15               236 git.md
# 12.09.2026  13:56               615 Lecture 0. Jupyter demo.ipynb
# 12.09.2026  11:29               533 main.py
# 12.09.2026  11:15             1�032 ML-AI-Engineering.ipynb
# 12.09.2026  11:44               109 my_first_script.py
# 12.09.2026  12:21    <DIR>          new_fold
# 12.09.2026  11:06                40 README.md
#                7 File(s)          2�749 bytes
#                5 Dir(s)  53�687�422�976 bytes free

# %%
import time

for i in range(10):
    time.sleep(30)

l = [1, 2, 3, 4]

# %% [markdown]
# - One
#     - Sublist
#         - This
#     - Sublist
#         - That
#         - The other thing
# - Two
#     - Sublist
# - Three
#     - Sublist

# %%
[x**2 for x in range(10, 11)]
# Out:
# [100]

# %%
s = 'Hello world!'

# %%
print(s)
# Out:
# Hello world!
